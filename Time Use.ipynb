# %%
#time use survey
#key = 4f06deabdbfc4c768f33f36c77776e62
import os
import pandas as pd
doc_root = os.path.join(os.environ['HOME'],'Downloads/a6_1115.xlsx')
data = pd.read_excel(doc_root, header = [1,2,3,4]).dropna() #drop na values
data
# Out:
# Own household child under age 18                                       Own household child under age 18  \
# Activity                                           Average hours per day spent in primary activities(1)
#                                                                                         Married mothers
#                                                                                      Employed full time
# Total, all activities                                                                           24.00
# Personal care activities                                                                         9.04
# Sleeping                                                                                         8.21
# Household activities                                                                             1.86
# Housework                                                                                        0.74
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
